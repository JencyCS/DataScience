# %% [markdown]
# <a href="https://colab.research.google.com/github/JencyCS/DataScience/blob/main/Hypothesis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sheth L.U.J and Sir M.V. College

# %% [markdown]
# Jency Nadar T095

# %% [markdown]
# t-test to evaluate whether our hypothesis is correct or not

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

# Load dataset from CSV
df = pd.read_csv("children_weight.csv")

# Extract weight column as numpy array
data = df['weight'].values
print("Data:", data)

# Hypotheses
H0 = "The average weight of 10-year-old children is 32 kg."
H1 = "The average weight of 10-year-old children is greater than 32 kg."

# Two-tailed t-test
t_stat, p_two_tailed = stats.ttest_1samp(data, 32)

# Convert to one-tailed p-value (testing mean > 32)
if t_stat > 0:
    p_one_tailed = p_two_tailed / 2
else:
    p_one_tailed = 1 - (p_two_tailed / 2)

# Print results
print("Test Statistic:", t_stat)
print("Two-tailed p-value:", p_two_tailed)
print("One-tailed p-value:", p_one_tailed)

# Conclusion
alpha = 0.05
if p_one_tailed < alpha:
    print("Reject H0: The average weight is significantly greater than 32 kg.")
else:
    print("Fail to reject H0: Insufficient evidence that the average weight > 32 kg.")
# Out:
# Data: [28 30 31 29 33 35 32 34 36 30 29 31 33 34 28 32 37 35 30 33]
# Test Statistic: 0.0
# Two-tailed p-value: 1.0
# One-tailed p-value: 0.5
# Fail to reject H0: Insufficient evidence that the average weight > 32 kg.

# %% [markdown]
# Two sampled T-test

# %%
from scipy.stats import ttest_ind
import numpy as np

week1 = np.genfromtxt("week1.csv", delimiter=",")
week2 = np.genfromtxt("week2.csv", delimiter=",")

# Remove NaN values if present
week1 = week1[~np.isnan(week1)]
week2 = week2[~np.isnan(week2)]

print("week1 data :-")
print(week1)
print("week2 data :-")
print(week2)

week1_mean = np.mean(week1)
week2_mean = np.mean(week2)
print("week1 mean value:", week1_mean)
print("week2 mean value:", week2_mean)

week1_std = np.std(week1)
week2_std = np.std(week2)
print("week1 std value:", week1_std)
print("week2 std value:", week2_std)

ttest, pval = ttest_ind(week1, week2)
print("p-value:", pval)

if pval < 0.05:
    print("we reject null hypothesis")
else:
    print("we accept null hypothesis")
# Out:
# week1 data :-
# [31. 30. 29. 33. 34. 35. 30. 31. 32. 32. 31. 30. 29. 33. 34. 35. 30. 31.
#  32. 32. 31. 30. 29. 33. 34. 35. 30. 31. 32. 32. 31. 30. 29. 33. 34. 35.
#  30. 31. 32.]
# week2 data :-
# [36. 35. 33. 37. 38. 36. 35. 34. 33. 34. 36. 35. 33. 37. 38. 36. 35. 34.
#  33. 34. 36. 35. 33. 37. 38. 36. 35. 34. 33.]
# week1 mean value: 31.692307692307693
# week2 mean value: 35.13793103448276
# week1 std value: 1.8138194034694763
# week2 std value: 1.5914456219605968
# p-value: 2.27156578189614e-11
# we reject null hypothesis

# %% [markdown]
# Paired sampled t-test

# %%
import pandas as pd
from scipy import stats

# Read CSV as tab-separated
df = pd.read_csv("blood_pressure.csv", sep='\t')

# Clean column names
df.columns = df.columns.str.strip().str.lower()
print("Columns:", df.columns)

# Now use correct column names
print(df[['bp_before','bp_after']].describe())

# Paired t-test
ttest, pval = stats.ttest_rel(df['bp_before'], df['bp_after'])
print("p-value:", pval)

if pval < 0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# Columns: Index(['patient', 'bp_before', 'bp_after', 'bp_before,bp_after'], dtype='object')
#         bp_before    bp_after
# count   15.000000   15.000000
# mean   152.933333  142.800000
# std      4.589844    4.783902
# min    145.000000  135.000000
# 25%    149.500000  139.500000
# 50%    153.000000  143.000000
# 75%    156.500000  146.000000
# max    160.000000  150.000000
# p-value: 1.091630110333053e-14
# reject null hypothesis

# %% [markdown]
# When you can run a Z Test.

# %%
import pandas as pd
from scipy import stats
from statsmodels.stats import weightstats as stests
ztest ,pval = stests.ztest(df['bp_before'], x2=None, value=156)
print(float(pval))
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# 0.009661847869030673
# reject null hypothesis

# %% [markdown]
# Two-sample Z test

# %%
ztest ,pval1 = stests.ztest(df['bp_before'], x2=df['bp_after'],
                            value=0,alternative='two-sided')
print(float(pval1))
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# 3.2234081479857283e-09
# reject null hypothesis

# %% [markdown]
# Chi-Square Test

# %%
import numpy as np
import scipy.stats as stats

observed = np.array([[30, 10],
                     [20, 20]])

chi2, p, dof, expected = stats.chi2_contingency(observed)

print("Chi-Square Statistic:", chi2)
print("P-Value:", p)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:\n", expected)

alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a significant association.")
else:
    print("Fail to reject the null hypothesis: No significant association.")
# Out:
# Chi-Square Statistic: 4.32
# P-Value: 0.03766692222862869
# Degrees of Freedom: 1
# Expected Frequencies:
#  [[25. 15.]
#  [25. 15.]]
# Reject the null hypothesis: There is a significant association.

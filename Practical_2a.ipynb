# %% [markdown]
# <a href="https://colab.research.google.com/github/JencyCS/DataScience/blob/main/Practical_2a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Sheth L.U.J and Sir M.V. College

# %% [markdown]
# Jency Nadar T095

# %% [markdown]
# Various function used to load data:

# %%
#Load Data
from sklearn import datasets

digits = datasets. load_digits()
features = digits.data
target = digits. target
features [0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
#Craeting Stumlative datasets
#make_regression
from sklearn.datasets import make_regression

features, target, coefficients = make_regression(n_samples = 100,
n_features = 3,
n_informative = 3,
n_targets = 1,
noise = 0.0,
coef = True,
random_state = 1)

print("Feature Matrix \n {}". format (features [:3] ) )
print("Target Vector \n {}".format(target [:3] ) )
# Out:
# Feature Matrix
#  [[ 1.29322588 -0.61736206 -0.11044703]
#  [-2.793085    0.36633201  1.93752881]
#  [ 0.80186103 -0.18656977  0.0465673 ]]
# Target Vector
#  [-10.37865986  25.5124503   19.67705609]

# %%
#make_classification
from sklearn. datasets import make_classification

features, target = make_classification(n_samples = 100,
n_features = 3,
n_informative = 3,
n_redundant = 0,
n_classes = 2,
weights = [.25, .75],
random_state = 1)

print("Feature matrix\n {}".format(features [:3]) )
print("Target vector\n {}".format(target [:3]))
# Out:
# Feature matrix
#  [[ 1.06354768 -1.42632219  1.02163151]
#  [ 0.23156977  1.49535261  0.33251578]
#  [ 0.15972951  0.83533515 -0.40869554]]
# Target vector
#  [1 0 0]

# %%
#make_blobs(clustering)
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

features, target = make_blobs(n_samples = 100,
n_features = 2,
centers = 3,
cluster_std = 0.5,
shuffle = True,
random_state = 1)

print("Feature Matrix\n {}".format(features[:3]) )
print("Target Vector\n {}".format(target [:3]))

# plot
plt.scatter(features[:, 0], features[:, 1], c=target)
plt.show()
# Out:
# Feature Matrix
#  [[ -1.22685609   3.25572052]
#  [ -9.57463218  -4.38310652]
#  [-10.71976941  -4.20558148]]
# Target Vector
#  [0 1 1]

# %%
#loading CSV file
import pandas as pd
from google.colab import files

uploaded = files.upload()

# Load the CSV file
df = pd.read_csv("IRIS.csv")

# Show first few rows
print(df.head())

# Separate features and target (if 'species' is your target column)
features = df.drop(columns=['species'])
target = df['species']

print(features.shape)
print(target.unique())
# Out:
#      <input type="file" id="files-eb8c8778-aec4-480f-83a4-b8f719b4bfc0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb8c8778-aec4-480f-83a4-b8f719b4bfc0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#loading excel file
import pandas as pd
from google.colab import files

uploaded = files.upload()

df = pd.read_excel("IRIS.xlsx")

features = df.drop(columns=['species'])
target = df['species']

print(features.shape)
print(target.unique())
# Out:
#      <input type="file" id="files-83c60ab7-dca5-4bb8-8a81-583120f1d757" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83c60ab7-dca5-4bb8-8a81-583120f1d757">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#load json file
from google.colab import files
import pandas as pd

# Upload file
uploaded = files.upload()

# Load JSON
df = pd.read_json("IRIS.json")

# View first few rows
print(df.head())
# Out:
#      <input type="file" id="files-6e001967-86ce-44bc-b64f-dcc75c11f3e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e001967-86ce-44bc-b64f-dcc75c11f3e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#sql query
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv("IRIS.csv")

engine = create_engine('sqlite:///iris.db')
print(pd.read_sql('SELECT * FROM iris LIMIT 5', engine))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
